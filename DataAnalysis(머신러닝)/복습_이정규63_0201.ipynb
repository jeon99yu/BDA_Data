# %% [markdown]
# ---
#
# # ** `scipy.spatial.distance` 주요 메서드 정리**
# 모든 메서드는 벡터(또는 행렬) 간 거리를 계산하는 데 사용됩니다.
#
# ## **1. 유클리드 기반 거리 (Euclidean-based Distances)**
# | 메서드 | 설명 | 공식 |
# |--------|------|------|
# | `euclidean(u, v)` | 유클리드 거리 (직선 거리) | \( d = \sqrt{\sum (u_i - v_i)^2} \) |
# | `sqeuclidean(u, v)` | 제곱 유클리드 거리 (제곱 값만 반환) | \( d = \sum (u_i - v_i)^2 \) |
#
# ---
#
# ## **2. 맨해튼 및 민코프스키 거리 (Minkowski-based Distances)**
# | 메서드 | 설명 | 공식 |
# |--------|------|------|
# | `cityblock(u, v)` | 맨해튼 거리 (택시 거리) | \( d = \sum |u_i - v_i| \) |
# | `minkowski(u, v, p)` | 민코프스키 거리 (p 값을 조절) | \( d = \left( \sum |u_i - v_i|^p \right)^{\frac{1}{p}} \) |
# | `chebyshev(u, v)` | 쳬비쇼프 거리 (최대 차이값) | \( d = \max |u_i - v_i| \) |
#
# ---
#
# ## **3. 마할라노비스 거리 (Mahalanobis Distance)**
# | 메서드 | 설명 | 공식 |
# |--------|------|------|
# | `mahalanobis(u, v, VI)` | 마할라노비스 거리 (공분산 행렬 고려) | \( d = \sqrt{(u - v)^T S^{-1} (u - v)} \) |
#
# **파라미터**
# - `VI`: 공분산 행렬의 역행렬 (\( S^{-1} \))
#
# ---
#
# ## **4. 확률 기반 거리 (Probability-based Distances)**
# | 메서드 | 설명 | 공식 |
# |--------|------|------|
# | `cosine(u, v)` | 코사인 거리 (유사도와 반대 개념) | \( d = 1 - \frac{u \cdot v}{\|u\|\|v\|} \) |
# | `correlation(u, v)` | 피어슨 상관 거리 | \( d = 1 - \frac{\sum (u_i - \bar{u})(v_i - \bar{v})}{\sqrt{\sum (u_i - \bar{u})^2} \sqrt{\sum (v_i - \bar{v})^2}} \) |
# | `jensenshannon(p, q)` | 젠슨-섀넌 거리 (확률 분포 차이) | \( d = \sqrt{\frac{1}{2} D_{KL}(p||m) + \frac{1}{2} D_{KL}(q||m)} \) |
# | `kulsinski(u, v)` | 쿨신스키 거리 (이진 데이터) | \( d = \frac{c_{10}}{c_{10} + c_{01} + c_{11}} \) |
#
# ---
#
# ## **5. 벡터 기반 거리 (Binary Distances, Set-based)**
# | 메서드 | 설명 | 공식 |
# |--------|------|------|
# | `hamming(u, v)` | 해밍 거리 (이진 데이터에서 다른 값 개수) | \( d = \frac{1}{n} \sum \mathbb{1}(u_i \neq v_i) \) |
# | `jaccard(u, v)` | 자카드 거리 (집합 차이) | \( d = 1 - \frac{|A \cap B|}{|A \cup B|} \) |
# | `dice(u, v)` | 다이스 거리 (자카드 거리의 변형) | \( d = 1 - \frac{2 |A \cap B|}{|A| + |B|} \) |
# | `rogerstanimoto(u, v)` | 로저스-타니모토 거리 (이진 벡터 비교) | \( d = \frac{2(c_{01} + c_{10})}{c_{00} + c_{11} + 2(c_{01} + c_{10})} \) |
# | `russellrao(u, v)` | 러셀-라오 거리 (두 벡터의 1의 개수 차이) | \( d = 1 - \frac{c_{11}}{n} \) |
# | `sokalmichener(u, v)` | 소칼-미크너 거리 (이진 데이터 거리 척도) | \( d = \frac{2(c_{01} + c_{10})}{2(c_{01} + c_{10}) + c_{00} + c_{11}} \) |
# | `sokalsneath(u, v)` | 소칼-스니스 거리 (군집 분석에서 사용) | \( d = \frac{c_{01} + c_{10}}{c_{01} + c_{10} + 2c_{11}} \) |
# | `yule(u, v)` | 율 거리 (이진 데이터 간 연관성) | \( d = \frac{c_{01} c_{10} - c_{00} c_{11}}{c_{01} c_{10} + c_{00} c_{11}} \) |
#
# ---
#
# ## **6. 거리 행렬 계산 (Pairwise Distance Matrix Calculation)**
# | 메서드 | 설명 |
# |--------|------|
# | `pdist(X, metric='euclidean')` | 행렬 X에서 모든 데이터 쌍에 대한 거리 계산 |
# | `cdist(XA, XB, metric='euclidean')` | 두 개의 행렬 \( XA \)와 \( XB \) 간의 거리 계산 |
# | `squareform(Y)` | 거리 벡터를 거리 행렬로 변환 |
#
# ---

# %%
import numpy as np
from scipy.spatial import distance

# %%
##.
p = np.array([1,2])
q = np.array([5,10])

# %%
p
# Out:
# array([1, 2])

# %%
q
# Out:
# array([ 5, 10])

# %%
## 유클리디안
## l1 norm, l2 norm 
np.linalg.norm(p-q)
# Out:
# 8.94427190999916

# %%
## 맨해튼 거리
np.sum(np.abs(p-q))
# Out:
# 12

# %%
#쳬비쇼프 거리
np.max(np.abs(p-q))
# Out:
# 8

# %%
## 민코프스키 거리 정규화
def min_dis(p,q,p_value):
    return np.sum(np.abs(p-q)**p_value)*(1/p_value)

min_dis(p,q,1)
# Out:
# 12.0

# %%
## numpy로 코사인 유사도 구할 수 있음
np.dot(p,q)/(np.linalg.norm(p)*np.linalg.norm(q))
# Out:
# 0.9999999999999999

# %% [markdown]
# ## distance 패키지로 거리 계산하기

# %%
distance.euclidean(p,q)
# Out:
# 8.94427190999916

# %%
distance.cityblock(p,q)
# Out:
# 12

# %%
distance.chebyshev(p,q)
# Out:
# 8

# %%
1 - distance.cosine(p,q)
# Out:
# 1

# %%
import seaborn as sns
df=sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
##스타벅스 데이터를 가지고 와서 계산해 보자!
import pandas as pd 
df = pd.read_csv('C:/Users/user/BDA_Data/Dataset/Starbucks_Seoul.csv')

# %%
df
# Out:
#          name                                   address gu_name   latitude  \
# 0        GS타워                   서울특별시 강남구 논현로 508 (역삼동)     강남구  37.501859
# 1    SSG마켓도곡R  서울특별시 강남구 언주로30길 57, 타워팰리스Ⅱ F 지하1층 (도곡동)     강남구  37.490298
# 2      W-Mall                  서울특별시 금천구 디지털로 188 (가산동)     금천구  37.477305
# 3       가든파이브             서울특별시 송파구 충민로 10 (문정동) 가든파이브툴     송파구  37.478232
# 4        가락본동                서울특별시 송파구 송파대로30길 13 (가락동)     송파구  37.494895
# ..        ...                                       ...     ...        ...
# 516     황학사거리          서울특별시 성동구 왕십리로 410 (하왕십리동, 센트라스)     성동구  37.567644
# 517      황학캐슬          서울특별시 중구 청계천로 400 (황학동) 롯데캐슬베네치아      중구  37.571240
# 518    회기역사거리                   서울특별시 동대문구 이문로 37 (회기동)    동대문구  37.590784
# 519       회현역              서울특별시 중구 퇴계로 72 (회현동) 리더스뷰남산      중구  37.558981
# 520    효창공원앞역     서울특별시 용산구 백범로 313 (효창동, 용산 롯데캐슬 센터포레)     용산구  37.539305
#
#       longitude
# 0    127.037278
# 1    127.054895
# 2    126.887691
# 3    127.119370
# 4    127.118785
# ..          ...
# 516  127.023697
# 517  127.022905
# 518  127.056098
# 519  126.980747
# 520  126.963060
#
# [521 rows x 5 columns]

# %%
## 위도 경도로 거리 계산
## 폴리옴으로 시각화까지 해보자!
from geopy.distance import geodesic
import folium

# %%
df_gn=df[df['gu_name']=='강남구']

# %%
#유클리디안 거리로 계산
#cdist(XA, XB, metric='euclidean')

pd.DataFrame(distance.cdist(df_gn[['latitude','longitude']],df_gn[['latitude','longitude']], metric= 'euclidean'))
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.000000  0.021072  0.026433  0.009764  0.015250  0.018504  0.011801
# 1   0.021072  0.000000  0.046763  0.027475  0.029620  0.029269  0.032036
# 2   0.026433  0.046763  0.000000  0.026345  0.020691  0.024873  0.020400
# 3   0.009764  0.027475  0.026345  0.000000  0.022807  0.026967  0.006152
# 4   0.015250  0.029620  0.020691  0.022807  0.000000  0.005013  0.020668
# ..       ...       ...       ...       ...       ...       ...       ...
# 75  0.025301  0.015845  0.051083  0.025980  0.038969  0.040379  0.032024
# 76  0.020516  0.036266  0.016349  0.026426  0.006650  0.009064  0.022881
# 77  0.014368  0.034306  0.012463  0.017092  0.010690  0.015668  0.012623
# 78  0.031450  0.015647  0.053178  0.040057  0.032965  0.030200  0.043250
# 79  0.018483  0.006505  0.042571  0.026632  0.024128  0.023220  0.030182
#
#           7         8         9   ...        70        71        72        73  \
# 0   0.009316  0.010609  0.011406  ...  0.024446  0.026520  0.003460  0.021053
# 1   0.025948  0.030598  0.024077  ...  0.020568  0.025590  0.018632  0.015764
# 2   0.027894  0.021639  0.032134  ...  0.040781  0.039268  0.028217  0.040291
# 3   0.001771  0.004747  0.005861  ...  0.034180  0.036251  0.013115  0.030604
# 4   0.023210  0.020534  0.026304  ...  0.020090  0.018906  0.014228  0.019921
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 75  0.024216  0.030527  0.020378  ...  0.035705  0.040414  0.024954  0.030751
# 76  0.027195  0.023179  0.030785  ...  0.025444  0.023238  0.020185  0.026003
# 77  0.018223  0.013173  0.022254  ...  0.029885  0.029387  0.015819  0.028650
# 78  0.038838  0.042021  0.038005  ...  0.014639  0.019238  0.028130  0.013057
# 79  0.025369  0.028877  0.024544  ...  0.014333  0.019226  0.015396  0.009420
#
#           74        75        76        77        78        79
# 0   0.020932  0.025301  0.020516  0.014368  0.031450  0.018483
# 1   0.017418  0.015845  0.036266  0.034306  0.015647  0.006505
# 2   0.039065  0.051083  0.016349  0.012463  0.053178  0.042571
# 3   0.030606  0.025980  0.026426  0.017092  0.040057  0.026632
# 4   0.018544  0.038969  0.006650  0.010690  0.032965  0.024128
# ..       ...       ...       ...       ...       ...       ...
# 75  0.032159  0.000000  0.045129  0.039556  0.030894  0.021422
# 76  0.024479  0.045129  0.000000  0.010570  0.039045  0.030756
# 77  0.027630  0.039556  0.010570  0.000000  0.041256  0.030170
# 78  0.014582  0.030894  0.039045  0.041256  0.000000  0.013496
# 79  0.010989  0.021422  0.030756  0.030170  0.013496  0.000000
#
# [80 rows x 80 columns]

# %%
city_gn=distance.cdist(df_gn[['latitude','longitude']],df_gn[['latitude','longitude']], metric= 'cityblock')

# %%
city_gn
# Out:
# array([[0.        , 0.0291786 , 0.0369527 , ..., 0.01933704, 0.03503944,
#         0.0228356 ],
#        [0.0291786 , 0.        , 0.0661313 , ..., 0.04851564, 0.02133776,
#         0.006663  ],
#        [0.0369527 , 0.0661313 , 0.        , ..., 0.01761566, 0.07199214,
#         0.0597883 ],
#        ...,
#        [0.01933704, 0.04851564, 0.01761566, ..., 0.        , 0.05437648,
#         0.04217264],
#        [0.03503944, 0.02133776, 0.07199214, ..., 0.05437648, 0.        ,
#         0.01467476],
#        [0.0228356 , 0.006663  , 0.0597883 , ..., 0.04217264, 0.01467476,
#         0.        ]])

# %%
dist_city_gn =pd.DataFrame(data=city_gn, columns = df_gn['name'])
dist_city_gn.set_index(df_gn['name'], inplace=True)

# %%
dist_city_gn
# Out:
# name          GS타워  SSG마켓도곡R      가로수길       강남R     강남구청역    강남구청정문  \
# name
# GS타워      0.000000  0.029179  0.036953  0.012987  0.018691  0.025039
# SSG마켓도곡R  0.029179  0.000000  0.066131  0.033869  0.039939  0.036783
# 가로수길      0.036953  0.066131  0.000000  0.032262  0.026193  0.029348
# 강남R       0.012987  0.033869  0.032262  0.000000  0.031678  0.038026
# 강남구청역     0.018691  0.039939  0.026193  0.031678  0.000000  0.006348
# ...            ...       ...       ...       ...       ...       ...
# 포이        0.031912  0.022241  0.068864  0.036602  0.042672  0.041224
# 학동사거리     0.021182  0.049007  0.017124  0.034169  0.009069  0.012224
# 학동역       0.019337  0.048516  0.017616  0.019229  0.012449  0.018797
# 학여울역      0.035039  0.021338  0.071992  0.040381  0.045799  0.042644
# 한티역       0.022836  0.006663  0.059788  0.027526  0.033596  0.030440
#
# name          강남대로    강남비젼타워     강남오거리      강남우성  ...    코엑스별마당    코엑스사거리  \
# name                                              ...
# GS타워      0.013012  0.012993  0.010863  0.015831  ...  0.031288  0.036323
# SSG마켓도곡R  0.042191  0.031364  0.040042  0.026083  ...  0.025232  0.030267
# 가로수길      0.023940  0.034767  0.026089  0.040048  ...  0.051659  0.046292
# 강남R       0.008322  0.002505  0.006173  0.007786  ...  0.044275  0.049310
# 강남구청역     0.029142  0.031684  0.029039  0.034522  ...  0.025467  0.020100
# ...            ...       ...       ...       ...  ...       ...       ...
# 포이        0.044924  0.034097  0.042775  0.028816  ...  0.047473  0.052508
# 학동사거리     0.031633  0.034175  0.031530  0.037013  ...  0.034535  0.029168
# 학동역       0.016693  0.019235  0.016590  0.022433  ...  0.034044  0.030081
# 학여울역      0.048052  0.040387  0.045903  0.043225  ...  0.020333  0.025700
# 한티역       0.035848  0.025712  0.033699  0.028550  ...  0.018569  0.023604
#
# name          큰길타워       포스코    포스코사거리        포이     학동사거리       학동역  \
# name
# GS타워      0.003930  0.024589  0.025821  0.031912  0.021182  0.019337
# SSG마켓도곡R  0.026264  0.018533  0.019765  0.022241  0.049007  0.048516
# 가로수길      0.039867  0.053740  0.051431  0.068864  0.017124  0.017616
# 강남R       0.016917  0.037576  0.038808  0.036602  0.034169  0.019229
# 강남구청역     0.014761  0.027548  0.025238  0.042672  0.009069  0.012449
# ...            ...       ...       ...       ...       ...       ...
# 포이        0.028997  0.040774  0.042006  0.000000  0.051740  0.051249
# 학동사거리     0.022743  0.036616  0.034307  0.051740  0.000000  0.014940
# 학동역       0.022252  0.036125  0.033815  0.051249  0.014940  0.000000
# 학여울역      0.032125  0.018252  0.020561  0.043579  0.054868  0.054376
# 한티역       0.019921  0.011870  0.013102  0.028904  0.042664  0.042173
#
# name          학여울역       한티역
# name
# GS타워      0.035039  0.022836
# SSG마켓도곡R  0.021338  0.006663
# 가로수길      0.071992  0.059788
# 강남R       0.040381  0.027526
# 강남구청역     0.045799  0.033596
# ...            ...       ...
# 포이        0.043579  0.028904
# 학동사거리     0.054868  0.042664
# 학동역       0.054376  0.042173
# 학여울역      0.000000  0.014675
# 한티역       0.014675  0.000000
#
# [80 rows x 80 columns]

# %%
## 지도에 좌표를 찍어서 확인해 보자!

def cal_euc_dis(row1, row2):
    pnt1 = np.array([row1['latitude'],row1['longitude']])
    pnt2 = np.array([row2['latitude'],row2['longitude']])
    return np.linalg.norm(pnt1- pnt2)

# %%
## 지도에 기준점이 필요하다. 
## 기준점은 평균으로 잡고 각 거리를 계산해 보자

map_center =[df_gn['latitude'].mean(), df_gn['longitude'].mean()]

#folium 시각화를 해서 지도 위치 시각화

m =folium.Map(location=map_center, zoom_start=10)

# %%
## 모든 위치에 있는 스타벅스 강남구 매장들 마커 찍어서 거리 계산하면 된다.

for idx, row in df_gn.iterrows():
    folium.Marker(location = [row['latitude'], row['longitude']], popup=row['name']).add_to(m)
    
## 첫 번째 스타트할 포인트
start_point = df_gn.iloc[0]

## 첫 번째 지점과 나머지 다른 지점들의 거리를 계산해서 지도에 표시하는 것
for idx,row in df_gn.iterrows():
    if start_point['name'] != row['name']:
        dis = cal_euc_dis(start_point, row)
        folium.PolyLine(locations = [[start_point['latitude'], start_point['longitude']],
                                    [row['latitude'],row['longitude']]]).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bfe00e487b53b7d519d3214f7f1cc194 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bfe00e487b53b7d519d3214f7f1cc194&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bfe00e487b53b7d519d3214f7f1cc194 = L.map(
#                 &quot;map_bfe00e487b53b7d519d3214f7f1cc194&quot;,
#                 {
#                     center: [37.507602992750016, 127.04461081],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c4c83272a6c5b9a7ac24b730a4a1596e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c4c83272a6c5b9a7ac24b730a4a1596e.addTo(map_bfe00e487b53b7d519d3214f7f1cc194);
#
#
#             var marker_e051c56b6d55ea2748ac30b43bee24df = L.marker(
#                 [37.5018592, 127.0372776],
#                 {
# }
#             ).addTo(map_bfe00e487b53b7d519d3214f7f1cc194);
#
#
#         var popup_b05613d4902627406a8ddc2ac4442b52 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_200c864038ae0bc5f8d16fae0cd0f00f = $(`&lt;div id=&quot;html_200c864038ae0bc5f8d16fae0cd0f00f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GS타워&lt;/div&gt;`)[0];
#                 popup_b05613d4902627406a8ddc2ac4442b52.setContent(html_200c864038ae0bc5f8d16fae0cd0f00f);
#
#
#
#         marker_e051c56b6d55ea2748ac30b43bee24df.bindPopup(popup_b05613d4902627406a8ddc2ac4442b52)
#         ;
#
#
#
#
#             var marker_b3e1d8b96b78889e4576fc1a2a2fffce = L.marker(
#                 [37.490298, 127.054895],
#                 {
# }
#             ).addTo(map_bfe00e487b53b7d519d3214f7f1cc194);
#
#
#         var popup_4d3e9d05e3d4c1a61397b1440c257810 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad5f521d3c9f3aa2e9b30b3933d727ab = $(`&lt;div id=&quot;html_ad5f521d3c9f3aa2e9b30b3933d727ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;SSG마켓도곡R&lt;/div&gt;`)[0];
#                 popup_4d3e9d05e3d4c1a61397b1440c257810.setContent(html_ad5f521d3c9f3aa2e9b30b3933d727ab);
#
#
#
#         marker_b3e1d8b96b78889e4576fc1a2a2fffce.bindPopup(popup_4d3e9d05e3d4c1a61397b1440c257810)
#         ;
#
#
#
#
#             var marker_dd4aea524de9e55a551431396a8dcda2 = L.marker(
#                 [37.5231593, 127.021625],
#                 {
# }
#             ).addTo(map_bfe00e487b53b7d519d3214f7f1cc194);
#
#
#         var popup_2542b6069df555385a4a94ba621bb0c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d885ce68449f6b0fa3899b24511dfda7 = $(`&lt;div id=&quot;html_d885ce68449f6b0fa3899b24511dfda7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가로수길&lt;/div&gt;`)[0];
#                 popup_2542b6069df555385a4a94ba621bb0c0.setContent(html_d885ce68449f6b0fa3899b24511dfda7);
#
#
#
#         marker_dd4aea524de9e55a551431396a8dcda2.bindPopup(popup_2542b6069df555385a4a94ba621bb0c0)
#         ;
#
#
#
#
#             var marker_0127bde03e51431bd8b21675c4f726b5 = L.marker(
#                 [37.497711, 127.028439],
#                 {
# }
#             ).addTo(map_bfe00e487b53b7d519d3214f7f1cc194);
#
#
#         var popup_2c2f62a271d6adcf71ddc5d2b458c9d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4cc282e42c80577b7684ea4d3f160a7 = $(`&lt;div id=&quot;html_b4cc282e42c80577b7684ea4d3f160a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강남R&lt;/div&gt;`)[0];
#                 popup_2c2f62a271d6adcf71ddc5d2b458c9d4.setContent(html_b4cc282e42c80577b7684ea4d3f160a7);
#
#
#
#         marker_0127bde03e51431bd8b21675c4f726b5.bindPopup(popup_2c2f62a271d6adcf71ddc5d2b458c9d4)
#         ;
#
#
#
#
#             var marker_3b9fdc64cc657cc8759aa000418eaa08 = L.marker(
#                 [37.5165849, 127.0412433],
#                 {
# }
#             ).addTo(map_bfe00e487b53b7d519d3214f7f1cc194);
#
#
#         var popup_32c604839126c9a3f3e6f16612c829c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22a2006db0edb5ebaa2888c1ba072145 = $(`&lt;div id=&quot;html_22a2006db0edb5ebaa2888c1ba072145&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강남구청역&lt;/div&gt;`)[0];
#                 popup_32c604839126c9a3f3e6f16612c829c0.setContent(html_22a2006db0edb5ebaa2888c1ba072145);
#
#
#
#         marker_3b9fdc64cc657cc8759aa000418eaa08.bindPopup(popup_32c604839126c9a3f3e6f16612c829c0)
#         ;
#
#
#
#
#             var marker_df28a714ca19b2fe51de4536beb143c2 = L.marker(
#                 [37.518181, 127.045995],
#                 {
# }
#             )
